# %%
import pandas as pd 
import numpy as np

YEARS = [str(y) for y in range(1990,2019)]

df = pd.DataFrame(columns=np.concatenate((["ID"], YEARS), axis=None))
a = set()
a.add(1)
a.add(2)
a.add(3)
df["ID"] = list(a)

# %%
df
# Out:
#    ID 1990 1991 1992 1993 1994 1995 1996 1997 1998  ... 2009 2010 2011 2012  \
# 0   1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 1   2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
# 2   3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN  NaN
#
#   2013 2014 2015 2016 2017 2018
# 0  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN
#
# [3 rows x 30 columns]
