# %%
import itertools
import random
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path 
import sys
import threading
import os
from IPython.display import clear_output

# %%
## Find the starting collaboration year for each author
def get_start_Y(df, id):
    aut = df.loc[df["ID"] == id]
    start_year = 0
    for year in aut.columns[1:]:
        n_colls = aut[year].values[0]
        
        if(n_colls != 0):
            start_year = year
        return start_year

## return all IDs of authors that have started to collaborate in the given year
 # param 'year' is a String
def get_authors_by_Y(year, df): 
    i = 0
    IDs = []
    
    for id in df["ID"]:
        aut = df.loc[df["ID"] == id]
        start_y = get_start_Y(df, id)
        
        if(year == start_y):
            IDs.append(aut["ID"].values[0])
            
        i += 1
        
        #clear_output(wait=True)
        if(i%1000==0):
            print(i, "/", len(df["ID"]), " for year: ", year, end='\r')
        
    return IDs

# %%
## This method return a DF for the given year, containing the timeseries of each author that starterd to collaborate on that year
def splitDF_by_start_Y(df, y):
    
    YEARS = [str(year) for year in range(1990,2019)]    
    i = YEARS.index(str(y))

    IDs = get_authors_by_Y(YEARS[i], df)
    start_y_Dfs = df[df.ID.isin(IDs)]

    cols = YEARS[i:]
    cols.insert(0, "ID")
    
    return start_y_Dfs[cols]

# %%
min_size = 0
max_size = 28

# Read active authors by hole lenght
for size in range(min_size, max_size+1):
    path = 'myDATA/05-filtered_by_hole_size/filtered_by_hole_size_'+str(size)+'.csv'
    
    if os.path.exists(path) and not os.path.exists('myDATA/10-splitted_by_hole_size_'+str(size)):
        df = pd.read_csv(path)
        os.mkdir('myDATA/10-splitted_by_hole_size_'+str(size))
        
        YEARS = [str(year) for year in range(1990,2019)]    
        for y in YEARS:
            print("splitting for hole size " + str(size) + " for year " + y + "\n", end='\r')
            # write a .csv for each year Y with all authors that started collaborating in Y.
             # it contains their collaborations form Y until 2018
            df_y = splitDF_by_start_Y(df, y)
            df_y.to_csv('myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv', index=False)
# Out:
# splitting for hole size 7 for year 1990
# splitting for hole size 7 for year 1991
# splitting for hole size 7 for year 1992
# splitting for hole size 7 for year 1993
# splitting for hole size 7 for year 1994
# splitting for hole size 7 for year 1995
# splitting for hole size 7 for year 1996
# splitting for hole size 7 for year 1997
# splitting for hole size 7 for year 1998
# splitting for hole size 7 for year 1999
# splitting for hole size 7 for year 2000
# splitting for hole size 7 for year 2001
# splitting for hole size 7 for year 2002
# splitting for hole size 7 for year 2003
# splitting for hole size 7 for year 2004
# splitting for hole size 7 for year 2005
# splitting for hole size 7 for year 2006
# splitting for hole size 7 for year 2007
# splitting for hole size 7 for year 2008
# splitting for hole size 7 for year 2009
# splitting for hole size 7 for year 2010
# splitting for hole size 7 for year 2011
# splitting for hole size 7 for year 2012
# splitting for hole size 7 for year 2013
# splitting for hole size 7 for year 2014
# splitting for hole size 7 for year 2015
# splitting for hole size 7 for year 2016
# splitting for hole size 7 for year 2017
# splitting for hole size 7 for year 2018
# splitting for hole size 8 for year 1990
# splitting for hole size 8 for year 1991
# splitting for hole size 8 for year 1992
# splitting for hole size 8 for year 1993
# splitting for hole size 8 for year 1994
# splitting for hole size 8 for year 1995
# splitting for hole size 8 for year 1996
# splitting for hole size 8 for year 1997
# splitting for hole size 8 for year 1998
# splitting for hole size 8 for year 1999
# splitting for hole size 8 for year 2000
# splitting for hole size 8 for year 2001
# splitting for hole size 8 for year 2002
# splitting for hole size 8 for year 2003
# splitting for hole size 8 for year 2004
# splitting for hole size 8 for year 2005
# splitting for hole size 8 for year 2006
# splitting for hole size 8 for year 2007
# splitting for hole size 8 for year 2008
# splitting for hole size 8 for year 2009
# splitting for hole size 8 for year 2010
# splitting for hole size 8 for year 2011
# splitting for hole size 8 for year 2012
# splitting for hole size 8 for year 2013
# splitting for hole size 8 for year 2014
# splitting for hole size 8 for year 2015
# splitting for hole size 8 for year 2016
# splitting for hole size 8 for year 2017
# splitting for hole size 8 for year 2018
# splitting for hole size 9 for year 1990
# splitting for hole size 9 for year 1991
# splitting for hole size 9 for year 1992
# splitting for hole size 9 for year 1993
# splitting for hole size 9 for year 1994
# splitting for hole size 9 for year 1995
# splitting for hole size 9 for year 1996
# splitting for hole size 9 for year 1997
# splitting for hole size 9 for year 1998
# splitting for hole size 9 for year 1999
# splitting for hole size 9 for year 2000
# splitting for hole size 9 for year 2001
# splitting for hole size 9 for year 2002
# splitting for hole size 9 for year 2003
# splitting for hole size 9 for year 2004
# splitting for hole size 9 for year 2005
# splitting for hole size 9 for year 2006
# splitting for hole size 9 for year 2007
# splitting for hole size 9 for year 2008
# splitting for hole size 9 for year 2009
# splitting for hole size 9 for year 2010
# splitting for hole size 9 for year 2011
# splitting for hole size 9 for year 2012
# splitting for hole size 9 for year 2013
# splitting for hole size 9 for year 2014
# splitting for hole size 9 for year 2015
# splitting for hole size 9 for year 2016
# splitting for hole size 9 for year 2017
# splitting for hole size 9 for year 2018
# splitting for hole size 10 for year 1990
# splitting for hole size 10 for year 1991
# splitting for hole size 10 for year 1992
# splitting for hole size 10 for year 1993
# splitting for hole size 10 for year 1994
# splitting for hole size 10 for year 1995
# splitting for hole size 10 for year 1996
# splitting for hole size 10 for year 1997
# splitting for hole size 10 for year 1998
# splitting for hole size 10 for year 1999
# splitting for hole size 10 for year 2000
# splitting for hole size 10 for year 2001
# splitting for hole size 10 for year 2002
# splitting for hole size 10 for year 2003
# splitting for hole size 10 for year 2004
# splitting for hole size 10 for year 2005
# splitting for hole size 10 for year 2006
# splitting for hole size 10 for year 2007
# splitting for hole size 10 for year 2008
# splitting for hole size 10 for year 2009
# splitting for hole size 10 for year 2010
# splitting for hole size 10 for year 2011
# splitting for hole size 10 for year 2012
# splitting for hole size 10 for year 2013
# splitting for hole size 10 for year 2014
# splitting for hole size 10 for year 2015
# splitting for hole size 10 for year 2016
# splitting for hole size 10 for year 2017
# splitting for hole size 10 for year 2018
# splitting for hole size 11 for year 1990
# splitting for hole size 11 for year 1991
# splitting for hole size 11 for year 1992
# splitting for hole size 11 for year 1993
# splitting for hole size 11 for year 1994
# splitting for hole size 11 for year 1995
# splitting for hole size 11 for year 1996
# splitting for hole size 11 for year 1997
# splitting for hole size 11 for year 1998
# splitting for hole size 11 for year 1999
# splitting for hole size 11 for year 2000
# splitting for hole size 11 for year 2001
# splitting for hole size 11 for year 2002
# splitting for hole size 11 for year 2003
# splitting for hole size 11 for year 2004
# splitting for hole size 11 for year 2005
# splitting for hole size 11 for year 2006
# splitting for hole size 11 for year 2007
# splitting for hole size 11 for year 2008
# splitting for hole size 11 for year 2009
# splitting for hole size 11 for year 2010
# splitting for hole size 11 for year 2011
# splitting for hole size 11 for year 2012
# splitting for hole size 11 for year 2013
# splitting for hole size 11 for year 2014
# splitting for hole size 11 for year 2015
# splitting for hole size 11 for year 2016
# splitting for hole size 11 for year 2017
# splitting for hole size 11 for year 2018
# splitting for hole size 12 for year 1990
# splitting for hole size 12 for year 1991
# splitting for hole size 12 for year 1992
# splitting for hole size 12 for year 1993
# splitting for hole size 12 for year 1994
# splitting for hole size 12 for year 1995
# splitting for hole size 12 for year 1996
# splitting for hole size 12 for year 1997
# splitting for hole size 12 for year 1998
# splitting for hole size 12 for year 1999
# splitting for hole size 12 for year 2000
# splitting for hole size 12 for year 2001
# splitting for hole size 12 for year 2002
# splitting for hole size 12 for year 2003
# splitting for hole size 12 for year 2004
# splitting for hole size 12 for year 2005
# splitting for hole size 12 for year 2006
# splitting for hole size 12 for year 2007
# splitting for hole size 12 for year 2008
# splitting for hole size 12 for year 2009
# splitting for hole size 12 for year 2010
# splitting for hole size 12 for year 2011
# splitting for hole size 12 for year 2012
# splitting for hole size 12 for year 2013
# splitting for hole size 12 for year 2014
# splitting for hole size 12 for year 2015
# splitting for hole size 12 for year 2016
# splitting for hole size 12 for year 2017
# splitting for hole size 12 for year 2018
# splitting for hole size 13 for year 1990
# splitting for hole size 13 for year 1991
# splitting for hole size 13 for year 1992
# splitting for hole size 13 for year 1993
# splitting for hole size 13 for year 1994
# splitting for hole size 13 for year 1995
# splitting for hole size 13 for year 1996
# splitting for hole size 13 for year 1997
# splitting for hole size 13 for year 1998
# splitting for hole size 13 for year 1999
# splitting for hole size 13 for year 2000
# splitting for hole size 13 for year 2001
# splitting for hole size 13 for year 2002
# splitting for hole size 13 for year 2003
# splitting for hole size 13 for year 2004
# splitting for hole size 13 for year 2005
# splitting for hole size 13 for year 2006
# splitting for hole size 13 for year 2007
# splitting for hole size 13 for year 2008
# splitting for hole size 13 for year 2009
# 115000 / 200058  for year:  2009
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6f013086ee13> in <module>
#      15             # write a .csv for each year Y with all authors that started collaborating in Y.
#      16              # it contains their collaborations form Y until 2018
# ---> 17             df_y = splitDF_by_start_Y(df, y)
#      18             df_y.to_csv('myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv', index=False)
#
# <ipython-input-3-db4be2cb0613> in splitDF_by_start_Y(df, y)
#       5     i = YEARS.index(str(y))
#       6
# ----> 7     IDs = get_authors_by_Y(YEARS[i], df)
#       8     start_y_Dfs = df[df.ID.isin(IDs)]
#       9
#
# <ipython-input-2-f752f424eb37> in get_authors_by_Y(year, df)
#      17
#      18     for id in df["ID"]:
# ---> 19         aut = df.loc[df["ID"] == id]
#      20         start_y = get_start_Y(df, id)
#      21
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/.local/lib/python3.8/site-packages/pandas/core/arraylike.py in __eq__(self, other)
#      30     @unpack_zerodim_and_defer("__eq__")
#      31     def __eq__(self, other):
# ---> 32         return self._cmp_method(other, operator.eq)
#      33
#      34     @unpack_zerodim_and_defer("__ne__")
#
# ~/.local/lib/python3.8/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5499
#    5500         with np.errstate(all="ignore"):
# -> 5501             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5502
#    5503         return self._construct_result(res_values, name=res_name)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     246     """
#     247     # NB: We assume extract_array has already been called on left and right
# --> 248     lvalues = ensure_wrapped_if_datetimelike(left)
#     249     rvalues = ensure_wrapped_if_datetimelike(right)
#     250
#
# ~/.local/lib/python3.8/site-packages/pandas/core/construction.py in ensure_wrapped_if_datetimelike(arr)
#     429
#     430
# --> 431 def ensure_wrapped_if_datetimelike(arr):
#     432     """
#     433     Wrap datetime64 and timedelta64 ndarrays in DatetimeArray/TimedeltaArray.
#
# KeyboardInterrupt:
