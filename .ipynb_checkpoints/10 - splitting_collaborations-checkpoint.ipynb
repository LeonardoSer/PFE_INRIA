# %%
import itertools
import random
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path 
import sys
import threading
import os
from IPython.display import clear_output

# %%
## Find the starting collaboration year for each author
def get_start_Y(aut):
    YEARS = [str(year) for year in range(1990,2019)]    
    for y in YEARS:
        val = aut[y].values[0]
        if(val != 0):
            return y
        
# add starting publication year to each row of the dataset
def add_start_publication_y(df, pub_df):
    df["start_year"] = [0 for i in range(len(df))]
    i = 0
    for id in df["ID"]:
        
        if(i%500 == 0):
            print("done", i, "on", len(df), end='\r')
        i+=1
        
        aut = df.loc[df["ID"] == id]
        df.loc[df.ID == id, "start_year"] = get_start_Y(pub_df.loc[pub_df["ID"] == id])
    return df

# build a df for each possible starting year
def split_by_y(df):
    splitted = []
    YEARS = [str(year) for year in range(1990,2019)]    
    for y in YEARS:
        tmp_df = df.loc[df.start_year == y]
        tmp_df = tmp_df.drop(columns=[x for i,x in enumerate(YEARS) if int(x)<int(y)] )
        
        splitted.append(tmp_df)
    return splitted

# %%
publications_df = pd.read_csv('myDATA/02-publication_df.csv')
collaboration_df = pd.read_csv('myDATA/00-collaboration_df.csv')
collaboration_df_with_year = add_start_publication_y(collaboration_df, publications_df)
collaboration_df_with_year
# Out:
# done 4500 on 232838

# %%
min_size = 0
max_size = 28
YEARS = [str(year) for year in range(1990,2019)]  
publications_df = pd.read_csv('myDATA/02-publication_df.csv')

# Read active authors by hole lenght
for size in range(min_size, max_size+1):
    print((' \033[1m' + "HOLE SIZE "+str(size) + '\033[0m ').center(120, '='))
    path = 'myDATA/05-filtered_by_hole_size/filtered_by_hole_size_'+str(size)+'.csv'
    
    if not os.path.exists('myDATA/10-splitted_by_hole_size_'+str(size)):
        os.mkdir('myDATA/10-splitted_by_hole_size_'+str(size))
    
    if os.path.exists(path):
        
        df = pd.read_csv(path)
        df = add_start_publication_y(df, publications_df)
        
        # split the df by starting year
        splitted = split_by_y(df)
        
        for i in range(len(YEARS)):
            y = YEARS[i]
            file = 'myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv'
            
            # write a .csv for each year Y with all authors that started collaborating in Y.
             # it contains their collaborations form Y until 2018
            df_y = splitted[i]
            df_y = df_y.drop(columns=['start_year'])
            df_y.to_csv(file, index=False)
# Out:
# ================================================= HOLE SIZE 0 ==================================================
# ================================================= HOLE SIZE 1 ==================================================
# ================================================= HOLE SIZE 2 ==================================================
# ================================================= HOLE SIZE 3 ==================================================
# ================================================= HOLE SIZE 4 ==================================================
# ================================================= HOLE SIZE 5 ==================================================
# ================================================= HOLE SIZE 6 ==================================================
# ================================================= HOLE SIZE 7 ==================================================
# ================================================= HOLE SIZE 8 ==================================================
# ================================================= HOLE SIZE 9 ==================================================
# ================================================= HOLE SIZE 10 =================================================
# ================================================= HOLE SIZE 11 =================================================
# ================================================= HOLE SIZE 12 =================================================
# ================================================= HOLE SIZE 13 =================================================
# ================================================= HOLE SIZE 14 =================================================
# ================================================= HOLE SIZE 15 =================================================
# ================================================= HOLE SIZE 16 =================================================
# ================================================= HOLE SIZE 17 =================================================
# ================================================= HOLE SIZE 18 =================================================
# ================================================= HOLE SIZE 19 =================================================
# ================================================= HOLE SIZE 20 =================================================
# ================================================= HOLE SIZE 21 =================================================
# ================================================= HOLE SIZE 22 =================================================
# ================================================= HOLE SIZE 23 =================================================
# ================================================= HOLE SIZE 24 =================================================
# ================================================= HOLE SIZE 25 =================================================
# ================================================= HOLE SIZE 26 =================================================
# ================================================= HOLE SIZE 27 =================================================
# ================================================= HOLE SIZE 28 =================================================
# done 230000 on 230234

# %%
# Print the distribution of starting collaboration years for each active author and for each hole lenght
min_size = 0
max_size = 28

# Read active authors by hole lenght
for size in range(min_size, max_size+1):
    print((' \033[1m' + "HOLE SIZE "+str(size) + '\033[0m ').center(120, '='))

    n = 0
    path = 'myDATA/05-filtered_by_hole_size/filtered_by_hole_size_'+str(size)+'.csv'
    df = pd.read_csv(path)
    YEARS = [str(year) for year in range(1990,2019)]    
    for y in YEARS:

        file = 'myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv'
        df_y = pd.read_csv(file)
        print("splitted for hole size " + str(size) + " for year " + y + " -> they are " + str(len(df_y)) + "\n", end='\r')
        n += len(df_y)
    print("\n", n, len(df))
# Out:
# ================================================= HOLE SIZE 0 ==================================================
# splitted for hole size 0 for year 1990 -> they are 0
# splitted for hole size 0 for year 1991 -> they are 0
# splitted for hole size 0 for year 1992 -> they are 0
# splitted for hole size 0 for year 1993 -> they are 0
# splitted for hole size 0 for year 1994 -> they are 0
# splitted for hole size 0 for year 1995 -> they are 1
# splitted for hole size 0 for year 1996 -> they are 3
# splitted for hole size 0 for year 1997 -> they are 2
# splitted for hole size 0 for year 1998 -> they are 4
# splitted for hole size 0 for year 1999 -> they are 1
# splitted for hole size 0 for year 2000 -> they are 1
# splitted for hole size 0 for year 2001 -> they are 1
# splitted for hole size 0 for year 2002 -> they are 1
# splitted for hole size 0 for year 2003 -> they are 1
# splitted for hole size 0 for year 2004 -> they are 1
# splitted for hole size 0 for year 2005 -> they are 3
# splitted for hole size 0 for year 2006 -> they are 6
# splitted for hole size 0 for year 2007 -> they are 12
# splitted for hole size 0 for year 2008 -> they are 11
# splitted for hole size 0 for year 2009 -> they are 22
# splitted for hole size 0 for year 2010 -> they are 30
# splitted for hole size 0 for year 2011 -> they are 43
# splitted for hole size 0 for year 2012 -> they are 42
# splitted for hole size 0 for year 2013 -> they are 50
# splitted for hole size 0 for year 2014 -> they are 85
# splitted for hole size 0 for year 2015 -> they are 114
# splitted for hole size 0 for year 2016 -> they are 239
# splitted for hole size 0 for year 2017 -> they are 319
# splitted for hole size 0 for year 2018 -> they are 10412
#
#  11404 11404
# ================================================= HOLE SIZE 1 ==================================================
# splitted for hole size 1 for year 1990 -> they are 45
# splitted for hole size 1 for year 1991 -> they are 38
# splitted for hole size 1 for year 1992 -> they are 41
# splitted for hole size 1 for year 1993 -> they are 33
# splitted for hole size 1 for year 1994 -> they are 57
# splitted for hole size 1 for year 1995 -> they are 67
# splitted for hole size 1 for year 1996 -> they are 61
# splitted for hole size 1 for year 1997 -> they are 101
# splitted for hole size 1 for year 1998 -> they are 117
# splitted for hole size 1 for year 1999 -> they are 89
# splitted for hole size 1 for year 2000 -> they are 117
# splitted for hole size 1 for year 2001 -> they are 144
# splitted for hole size 1 for year 2002 -> they are 172
# splitted for hole size 1 for year 2003 -> they are 164
# splitted for hole size 1 for year 2004 -> they are 212
# splitted for hole size 1 for year 2005 -> they are 214
# splitted for hole size 1 for year 2006 -> they are 274
# splitted for hole size 1 for year 2007 -> they are 331
# splitted for hole size 1 for year 2008 -> they are 398
# splitted for hole size 1 for year 2009 -> they are 433
# splitted for hole size 1 for year 2010 -> they are 455
# splitted for hole size 1 for year 2011 -> they are 543
# splitted for hole size 1 for year 2012 -> they are 698
# splitted for hole size 1 for year 2013 -> they are 971
# splitted for hole size 1 for year 2014 -> they are 1454
# splitted for hole size 1 for year 2015 -> they are 2028
# splitted for hole size 1 for year 2016 -> they are 3594
# splitted for hole size 1 for year 2017 -> they are 11083
# splitted for hole size 1 for year 2018 -> they are 11955
#
#  35889 35889
# ================================================= HOLE SIZE 2 ==================================================
# splitted for hole size 2 for year 1990 -> they are 128
# splitted for hole size 2 for year 1991 -> they are 116
# splitted for hole size 2 for year 1992 -> they are 125
# splitted for hole size 2 for year 1993 -> they are 119
# splitted for hole size 2 for year 1994 -> they are 153
# splitted for hole size 2 for year 1995 -> they are 181
# splitted for hole size 2 for year 1996 -> they are 187
# splitted for hole size 2 for year 1997 -> they are 281
# splitted for hole size 2 for year 1998 -> they are 311
# splitted for hole size 2 for year 1999 -> they are 263
# splitted for hole size 2 for year 2000 -> they are 340
# splitted for hole size 2 for year 2001 -> they are 399
# splitted for hole size 2 for year 2002 -> they are 538
# splitted for hole size 2 for year 2003 -> they are 517
# splitted for hole size 2 for year 2004 -> they are 586
# splitted for hole size 2 for year 2005 -> they are 621
# splitted for hole size 2 for year 2006 -> they are 819
# splitted for hole size 2 for year 2007 -> they are 887
# splitted for hole size 2 for year 2008 -> they are 1110
# splitted for hole size 2 for year 2009 -> they are 1180
# splitted for hole size 2 for year 2010 -> they are 1290
# splitted for hole size 2 for year 2011 -> they are 1524
# splitted for hole size 2 for year 2012 -> they are 1976
# splitted for hole size 2 for year 2013 -> they are 2597
# splitted for hole size 2 for year 2014 -> they are 3766
# splitted for hole size 2 for year 2015 -> they are 5341
# splitted for hole size 2 for year 2016 -> they are 11804
# splitted for hole size 2 for year 2017 -> they are 12163
# splitted for hole size 2 for year 2018 -> they are 13116
#
#  62438 62438
# ================================================= HOLE SIZE 3 ==================================================
# splitted for hole size 3 for year 1990 -> they are 217
# splitted for hole size 3 for year 1991 -> they are 182
# splitted for hole size 3 for year 1992 -> they are 202
# splitted for hole size 3 for year 1993 -> they are 231
# splitted for hole size 3 for year 1994 -> they are 277
# splitted for hole size 3 for year 1995 -> they are 298
# splitted for hole size 3 for year 1996 -> they are 352
# splitted for hole size 3 for year 1997 -> they are 465
# splitted for hole size 3 for year 1998 -> they are 532
# splitted for hole size 3 for year 1999 -> they are 437
# splitted for hole size 3 for year 2000 -> they are 607
# splitted for hole size 3 for year 2001 -> they are 698
# splitted for hole size 3 for year 2002 -> they are 925
# splitted for hole size 3 for year 2003 -> they are 835
# splitted for hole size 3 for year 2004 -> they are 1030
# splitted for hole size 3 for year 2005 -> they are 1014
# splitted for hole size 3 for year 2006 -> they are 1400
# splitted for hole size 3 for year 2007 -> they are 1451
# splitted for hole size 3 for year 2008 -> they are 1846
# splitted for hole size 3 for year 2009 -> they are 2019
# splitted for hole size 3 for year 2010 -> they are 2366
# splitted for hole size 3 for year 2011 -> they are 2709
# splitted for hole size 3 for year 2012 -> they are 3494
# splitted for hole size 3 for year 2013 -> they are 4423
# splitted for hole size 3 for year 2014 -> they are 6957
# splitted for hole size 3 for year 2015 -> they are 11671
# splitted for hole size 3 for year 2016 -> they are 12733
# splitted for hole size 3 for year 2017 -> they are 12857
# splitted for hole size 3 for year 2018 -> they are 13857
#
#  86085 86085
# ================================================= HOLE SIZE 4 ==================================================
# splitted for hole size 4 for year 1990 -> they are 282
# splitted for hole size 4 for year 1991 -> they are 230
# splitted for hole size 4 for year 1992 -> they are 282
# splitted for hole size 4 for year 1993 -> they are 328
# splitted for hole size 4 for year 1994 -> they are 371
# splitted for hole size 4 for year 1995 -> they are 425
# splitted for hole size 4 for year 1996 -> they are 519
# splitted for hole size 4 for year 1997 -> they are 645
# splitted for hole size 4 for year 1998 -> they are 737
# splitted for hole size 4 for year 1999 -> they are 607
# splitted for hole size 4 for year 2000 -> they are 839
# splitted for hole size 4 for year 2001 -> they are 935
# splitted for hole size 4 for year 2002 -> they are 1275
# splitted for hole size 4 for year 2003 -> they are 1130
# splitted for hole size 4 for year 2004 -> they are 1384
# splitted for hole size 4 for year 2005 -> they are 1374
# splitted for hole size 4 for year 2006 -> they are 1914
# splitted for hole size 4 for year 2007 -> they are 2018
# splitted for hole size 4 for year 2008 -> they are 2633
# splitted for hole size 4 for year 2009 -> they are 2916
# splitted for hole size 4 for year 2010 -> they are 3385
# splitted for hole size 4 for year 2011 -> they are 3910
# splitted for hole size 4 for year 2012 -> they are 4977
# splitted for hole size 4 for year 2013 -> they are 6900
# splitted for hole size 4 for year 2014 -> they are 12437
# splitted for hole size 4 for year 2015 -> they are 12290
# splitted for hole size 4 for year 2016 -> they are 13291
# splitted for hole size 4 for year 2017 -> they are 13359
# splitted for hole size 4 for year 2018 -> they are 14342
#
#  105735 105735
# ================================================= HOLE SIZE 5 ==================================================
# splitted for hole size 5 for year 1990 -> they are 322
# splitted for hole size 5 for year 1991 -> they are 272
# splitted for hole size 5 for year 1992 -> they are 347
# splitted for hole size 5 for year 1993 -> they are 415
# splitted for hole size 5 for year 1994 -> they are 448
# splitted for hole size 5 for year 1995 -> they are 515
# splitted for hole size 5 for year 1996 -> they are 659
# splitted for hole size 5 for year 1997 -> they are 775
# splitted for hole size 5 for year 1998 -> they are 912
# splitted for hole size 5 for year 1999 -> they are 746
# splitted for hole size 5 for year 2000 -> they are 1064
# splitted for hole size 5 for year 2001 -> they are 1130
# splitted for hole size 5 for year 2002 -> they are 1591
# splitted for hole size 5 for year 2003 -> they are 1394
# splitted for hole size 5 for year 2004 -> they are 1715
# splitted for hole size 5 for year 2005 -> they are 1732
# splitted for hole size 5 for year 2006 -> they are 2437
# splitted for hole size 5 for year 2007 -> they are 2612
# splitted for hole size 5 for year 2008 -> they are 3418
# splitted for hole size 5 for year 2009 -> they are 3761
# splitted for hole size 5 for year 2010 -> they are 4533
# splitted for hole size 5 for year 2011 -> they are 5052
# splitted for hole size 5 for year 2012 -> they are 7305
# splitted for hole size 5 for year 2013 -> they are 11392
# splitted for hole size 5 for year 2014 -> they are 12989
# splitted for hole size 5 for year 2015 -> they are 12681
# splitted for hole size 5 for year 2016 -> they are 13680
# splitted for hole size 5 for year 2017 -> they are 13697
# splitted for hole size 5 for year 2018 -> they are 14724
#
#  122318 122318
# ================================================= HOLE SIZE 6 ==================================================
# splitted for hole size 6 for year 1990 -> they are 375
# splitted for hole size 6 for year 1991 -> they are 309
# splitted for hole size 6 for year 1992 -> they are 395
# splitted for hole size 6 for year 1993 -> they are 482
# splitted for hole size 6 for year 1994 -> they are 515
# splitted for hole size 6 for year 1995 -> they are 604
# splitted for hole size 6 for year 1996 -> they are 766
# splitted for hole size 6 for year 1997 -> they are 893
# splitted for hole size 6 for year 1998 -> they are 1071
# splitted for hole size 6 for year 1999 -> they are 888
# splitted for hole size 6 for year 2000 -> they are 1249
# splitted for hole size 6 for year 2001 -> they are 1297
# splitted for hole size 6 for year 2002 -> they are 1879
# splitted for hole size 6 for year 2003 -> they are 1641
# splitted for hole size 6 for year 2004 -> they are 2026
# splitted for hole size 6 for year 2005 -> they are 2061
# splitted for hole size 6 for year 2006 -> they are 2886
# splitted for hole size 6 for year 2007 -> they are 3190
# splitted for hole size 6 for year 2008 -> they are 4125
# splitted for hole size 6 for year 2009 -> they are 4680
# splitted for hole size 6 for year 2010 -> they are 5612
# splitted for hole size 6 for year 2011 -> they are 7224
# splitted for hole size 6 for year 2012 -> they are 11510
# splitted for hole size 6 for year 2013 -> they are 11794
# splitted for hole size 6 for year 2014 -> they are 13327
# splitted for hole size 6 for year 2015 -> they are 12929
# splitted for hole size 6 for year 2016 -> they are 13976
# splitted for hole size 6 for year 2017 -> they are 13966
# splitted for hole size 6 for year 2018 -> they are 14984
#
#  136654 136654
# ================================================= HOLE SIZE 7 ==================================================
# splitted for hole size 7 for year 1990 -> they are 411
# splitted for hole size 7 for year 1991 -> they are 354
# splitted for hole size 7 for year 1992 -> they are 449
# splitted for hole size 7 for year 1993 -> they are 546
# splitted for hole size 7 for year 1994 -> they are 582
# splitted for hole size 7 for year 1995 -> they are 687
# splitted for hole size 7 for year 1996 -> they are 866
# splitted for hole size 7 for year 1997 -> they are 1016
# splitted for hole size 7 for year 1998 -> they are 1208
# splitted for hole size 7 for year 1999 -> they are 1024
# splitted for hole size 7 for year 2000 -> they are 1408
# splitted for hole size 7 for year 2001 -> they are 1462
# splitted for hole size 7 for year 2002 -> they are 2158
# splitted for hole size 7 for year 2003 -> they are 1853
# splitted for hole size 7 for year 2004 -> they are 2326
# splitted for hole size 7 for year 2005 -> they are 2381
# splitted for hole size 7 for year 2006 -> they are 3328
# splitted for hole size 7 for year 2007 -> they are 3758
# splitted for hole size 7 for year 2008 -> they are 4902
# splitted for hole size 7 for year 2009 -> they are 5551
# splitted for hole size 7 for year 2010 -> they are 7553
# splitted for hole size 7 for year 2011 -> they are 10971
# splitted for hole size 7 for year 2012 -> they are 11869
# splitted for hole size 7 for year 2013 -> they are 12072
# splitted for hole size 7 for year 2014 -> they are 13555
# splitted for hole size 7 for year 2015 -> they are 13117
# splitted for hole size 7 for year 2016 -> they are 14190
# splitted for hole size 7 for year 2017 -> they are 14149
# splitted for hole size 7 for year 2018 -> they are 15180
#
#  148926 148926
# ================================================= HOLE SIZE 8 ==================================================
# splitted for hole size 8 for year 1990 -> they are 437
# splitted for hole size 8 for year 1991 -> they are 391
# splitted for hole size 8 for year 1992 -> they are 489
# splitted for hole size 8 for year 1993 -> they are 605
# splitted for hole size 8 for year 1994 -> they are 634
# splitted for hole size 8 for year 1995 -> they are 770
# splitted for hole size 8 for year 1996 -> they are 938
# splitted for hole size 8 for year 1997 -> they are 1133
# splitted for hole size 8 for year 1998 -> they are 1342
# splitted for hole size 8 for year 1999 -> they are 1137
# splitted for hole size 8 for year 2000 -> they are 1577
# splitted for hole size 8 for year 2001 -> they are 1625
# splitted for hole size 8 for year 2002 -> they are 2387
# splitted for hole size 8 for year 2003 -> they are 2090
# splitted for hole size 8 for year 2004 -> they are 2586
# splitted for hole size 8 for year 2005 -> they are 2681
# splitted for hole size 8 for year 2006 -> they are 3785
# splitted for hole size 8 for year 2007 -> they are 4325
# splitted for hole size 8 for year 2008 -> they are 5741
# splitted for hole size 8 for year 2009 -> they are 7368
# splitted for hole size 8 for year 2010 -> they are 11142
# splitted for hole size 8 for year 2011 -> they are 11224
# splitted for hole size 8 for year 2012 -> they are 12085
# splitted for hole size 8 for year 2013 -> they are 12284
# splitted for hole size 8 for year 2014 -> they are 13756
# splitted for hole size 8 for year 2015 -> they are 13236
# splitted for hole size 8 for year 2016 -> they are 14349
# splitted for hole size 8 for year 2017 -> they are 14313
# splitted for hole size 8 for year 2018 -> they are 15328
#
#  159758 159758
# ================================================= HOLE SIZE 9 ==================================================
# splitted for hole size 9 for year 1990 -> they are 475
# splitted for hole size 9 for year 1991 -> they are 435
# splitted for hole size 9 for year 1992 -> they are 531
# splitted for hole size 9 for year 1993 -> they are 636
# splitted for hole size 9 for year 1994 -> they are 692
# splitted for hole size 9 for year 1995 -> they are 843
# splitted for hole size 9 for year 1996 -> they are 1023
# splitted for hole size 9 for year 1997 -> they are 1223
# splitted for hole size 9 for year 1998 -> they are 1483
# splitted for hole size 9 for year 1999 -> they are 1242
# splitted for hole size 9 for year 2000 -> they are 1720
# splitted for hole size 9 for year 2001 -> they are 1767
# splitted for hole size 9 for year 2002 -> they are 2617
# splitted for hole size 9 for year 2003 -> they are 2290
# splitted for hole size 9 for year 2004 -> they are 2824
# splitted for hole size 9 for year 2005 -> they are 2978
# splitted for hole size 9 for year 2006 -> they are 4331
# splitted for hole size 9 for year 2007 -> they are 5010
# splitted for hole size 9 for year 2008 -> they are 7514
# splitted for hole size 9 for year 2009 -> they are 10871
# splitted for hole size 9 for year 2010 -> they are 11422
# splitted for hole size 9 for year 2011 -> they are 11382
# splitted for hole size 9 for year 2012 -> they are 12206
# splitted for hole size 9 for year 2013 -> they are 12417
# splitted for hole size 9 for year 2014 -> they are 13888
# splitted for hole size 9 for year 2015 -> they are 13360
# splitted for hole size 9 for year 2016 -> they are 14470
# splitted for hole size 9 for year 2017 -> they are 14430
# splitted for hole size 9 for year 2018 -> they are 15459
#
#  169539 169539
# ================================================= HOLE SIZE 10 =================================================
# splitted for hole size 10 for year 1990 -> they are 505
# splitted for hole size 10 for year 1991 -> they are 467
# splitted for hole size 10 for year 1992 -> they are 564
# splitted for hole size 10 for year 1993 -> they are 686
# splitted for hole size 10 for year 1994 -> they are 729
# splitted for hole size 10 for year 1995 -> they are 915
# splitted for hole size 10 for year 1996 -> they are 1111
# splitted for hole size 10 for year 1997 -> they are 1320
# splitted for hole size 10 for year 1998 -> they are 1588
# splitted for hole size 10 for year 1999 -> they are 1337
# splitted for hole size 10 for year 2000 -> they are 1850
# splitted for hole size 10 for year 2001 -> they are 1918
# splitted for hole size 10 for year 2002 -> they are 2839
# splitted for hole size 10 for year 2003 -> they are 2510
# splitted for hole size 10 for year 2004 -> they are 3127
# splitted for hole size 10 for year 2005 -> they are 3342
# splitted for hole size 10 for year 2006 -> they are 4991
# splitted for hole size 10 for year 2007 -> they are 6565
# splitted for hole size 10 for year 2008 -> they are 11033
# splitted for hole size 10 for year 2009 -> they are 11100
# splitted for hole size 10 for year 2010 -> they are 11578
# splitted for hole size 10 for year 2011 -> they are 11499
# splitted for hole size 10 for year 2012 -> they are 12331
# splitted for hole size 10 for year 2013 -> they are 12514
# splitted for hole size 10 for year 2014 -> they are 13992
# splitted for hole size 10 for year 2015 -> they are 13463
# splitted for hole size 10 for year 2016 -> they are 14563
# splitted for hole size 10 for year 2017 -> they are 14528
# splitted for hole size 10 for year 2018 -> they are 15541
#
#  178506 178506
# ================================================= HOLE SIZE 11 =================================================
# splitted for hole size 11 for year 1990 -> they are 543
# splitted for hole size 11 for year 1991 -> they are 495
# splitted for hole size 11 for year 1992 -> they are 595
# splitted for hole size 11 for year 1993 -> they are 741
# splitted for hole size 11 for year 1994 -> they are 794
# splitted for hole size 11 for year 1995 -> they are 977
# splitted for hole size 11 for year 1996 -> they are 1187
# splitted for hole size 11 for year 1997 -> they are 1416
# splitted for hole size 11 for year 1998 -> they are 1725
# splitted for hole size 11 for year 1999 -> they are 1436
# splitted for hole size 11 for year 2000 -> they are 1997
# splitted for hole size 11 for year 2001 -> they are 2062
# splitted for hole size 11 for year 2002 -> they are 3077
# splitted for hole size 11 for year 2003 -> they are 2785
# splitted for hole size 11 for year 2004 -> they are 3452
# splitted for hole size 11 for year 2005 -> they are 3781
# splitted for hole size 11 for year 2006 -> they are 6330
# splitted for hole size 11 for year 2007 -> they are 9470
# splitted for hole size 11 for year 2008 -> they are 11223
# splitted for hole size 11 for year 2009 -> they are 11250
# splitted for hole size 11 for year 2010 -> they are 11693
# splitted for hole size 11 for year 2011 -> they are 11575
# splitted for hole size 11 for year 2012 -> they are 12404
# splitted for hole size 11 for year 2013 -> they are 12606
# splitted for hole size 11 for year 2014 -> they are 14091
# splitted for hole size 11 for year 2015 -> they are 13527
# splitted for hole size 11 for year 2016 -> they are 14643
# splitted for hole size 11 for year 2017 -> they are 14625
# splitted for hole size 11 for year 2018 -> they are 15614
#
#  186114 186114
# ================================================= HOLE SIZE 12 =================================================
# splitted for hole size 12 for year 1990 -> they are 566
# splitted for hole size 12 for year 1991 -> they are 521
# splitted for hole size 12 for year 1992 -> they are 625
# splitted for hole size 12 for year 1993 -> they are 784
# splitted for hole size 12 for year 1994 -> they are 835
# splitted for hole size 12 for year 1995 -> they are 1040
# splitted for hole size 12 for year 1996 -> they are 1272
# splitted for hole size 12 for year 1997 -> they are 1513
# splitted for hole size 12 for year 1998 -> they are 1834
# splitted for hole size 12 for year 1999 -> they are 1537
# splitted for hole size 12 for year 2000 -> they are 2166
# splitted for hole size 12 for year 2001 -> they are 2214
# splitted for hole size 12 for year 2002 -> they are 3322
# splitted for hole size 12 for year 2003 -> they are 3080
# splitted for hole size 12 for year 2004 -> they are 3881
# splitted for hole size 12 for year 2005 -> they are 4835
# splitted for hole size 12 for year 2006 -> they are 9089
# splitted for hole size 12 for year 2007 -> they are 9656
# splitted for hole size 12 for year 2008 -> they are 11382
# splitted for hole size 12 for year 2009 -> they are 11330
# splitted for hole size 12 for year 2010 -> they are 11777
# splitted for hole size 12 for year 2011 -> they are 11649
# splitted for hole size 12 for year 2012 -> they are 12477
# splitted for hole size 12 for year 2013 -> they are 12687
# splitted for hole size 12 for year 2014 -> they are 14169
# splitted for hole size 12 for year 2015 -> they are 13593
# splitted for hole size 12 for year 2016 -> they are 14722
# splitted for hole size 12 for year 2017 -> they are 14697
# splitted for hole size 12 for year 2018 -> they are 15682
#
#  192935 192935
# ================================================= HOLE SIZE 13 =================================================
# splitted for hole size 13 for year 1990 -> they are 605
# splitted for hole size 13 for year 1991 -> they are 558
# splitted for hole size 13 for year 1992 -> they are 662
# splitted for hole size 13 for year 1993 -> they are 813
# splitted for hole size 13 for year 1994 -> they are 888
# splitted for hole size 13 for year 1995 -> they are 1098
# splitted for hole size 13 for year 1996 -> they are 1339
# splitted for hole size 13 for year 1997 -> they are 1598
# splitted for hole size 13 for year 1998 -> they are 1950
# splitted for hole size 13 for year 1999 -> they are 1629
# splitted for hole size 13 for year 2000 -> they are 2301
# splitted for hole size 13 for year 2001 -> they are 2389
# splitted for hole size 13 for year 2002 -> they are 3599
# splitted for hole size 13 for year 2003 -> they are 3435
# splitted for hole size 13 for year 2004 -> they are 4860
# splitted for hole size 13 for year 2005 -> they are 6980
# splitted for hole size 13 for year 2006 -> they are 9235
# splitted for hole size 13 for year 2007 -> they are 9773
# splitted for hole size 13 for year 2008 -> they are 11461
# splitted for hole size 13 for year 2009 -> they are 11388
# splitted for hole size 13 for year 2010 -> they are 11828
# splitted for hole size 13 for year 2011 -> they are 11695
# splitted for hole size 13 for year 2012 -> they are 12526
# splitted for hole size 13 for year 2013 -> they are 12740
# splitted for hole size 13 for year 2014 -> they are 14225
# splitted for hole size 13 for year 2015 -> they are 13641
# splitted for hole size 13 for year 2016 -> they are 14778
# splitted for hole size 13 for year 2017 -> they are 14777
# splitted for hole size 13 for year 2018 -> they are 15732
#
#  198503 198503
# ================================================= HOLE SIZE 14 =================================================
# splitted for hole size 14 for year 1990 -> they are 626
# splitted for hole size 14 for year 1991 -> they are 584
# splitted for hole size 14 for year 1992 -> they are 690
# splitted for hole size 14 for year 1993 -> they are 855
# splitted for hole size 14 for year 1994 -> they are 929
# splitted for hole size 14 for year 1995 -> they are 1143
# splitted for hole size 14 for year 1996 -> they are 1410
# splitted for hole size 14 for year 1997 -> they are 1674
# splitted for hole size 14 for year 1998 -> they are 2047
# splitted for hole size 14 for year 1999 -> they are 1729
# splitted for hole size 14 for year 2000 -> they are 2425
# splitted for hole size 14 for year 2001 -> they are 2567
# splitted for hole size 14 for year 2002 -> they are 3886
# splitted for hole size 14 for year 2003 -> they are 4288
# splitted for hole size 14 for year 2004 -> they are 6662
# splitted for hole size 14 for year 2005 -> they are 7076
# splitted for hole size 14 for year 2006 -> they are 9308
# splitted for hole size 14 for year 2007 -> they are 9820
# splitted for hole size 14 for year 2008 -> they are 11501
# splitted for hole size 14 for year 2009 -> they are 11433
# splitted for hole size 14 for year 2010 -> they are 11864
# splitted for hole size 14 for year 2011 -> they are 11734
# splitted for hole size 14 for year 2012 -> they are 12579
# splitted for hole size 14 for year 2013 -> they are 12772
# splitted for hole size 14 for year 2014 -> they are 14272
# splitted for hole size 14 for year 2015 -> they are 13678
# splitted for hole size 14 for year 2016 -> they are 14824
# splitted for hole size 14 for year 2017 -> they are 14828
# splitted for hole size 14 for year 2018 -> they are 15776
#
#  202980 202980
# ================================================= HOLE SIZE 15 =================================================
# splitted for hole size 15 for year 1990 -> they are 657
# splitted for hole size 15 for year 1991 -> they are 615
# splitted for hole size 15 for year 1992 -> they are 718
# splitted for hole size 15 for year 1993 -> they are 900
# splitted for hole size 15 for year 1994 -> they are 969
# splitted for hole size 15 for year 1995 -> they are 1185
# splitted for hole size 15 for year 1996 -> they are 1481
# splitted for hole size 15 for year 1997 -> they are 1750
# splitted for hole size 15 for year 1998 -> they are 2152
# splitted for hole size 15 for year 1999 -> they are 1844
# splitted for hole size 15 for year 2000 -> they are 2603
# splitted for hole size 15 for year 2001 -> they are 2780
# splitted for hole size 15 for year 2002 -> they are 4692
# splitted for hole size 15 for year 2003 -> they are 5994
# splitted for hole size 15 for year 2004 -> they are 6722
# splitted for hole size 15 for year 2005 -> they are 7114
# splitted for hole size 15 for year 2006 -> they are 9356
# splitted for hole size 15 for year 2007 -> they are 9848
# splitted for hole size 15 for year 2008 -> they are 11533
# splitted for hole size 15 for year 2009 -> they are 11465
# splitted for hole size 15 for year 2010 -> they are 11895
# splitted for hole size 15 for year 2011 -> they are 11753
# splitted for hole size 15 for year 2012 -> they are 12611
# splitted for hole size 15 for year 2013 -> they are 12793
# splitted for hole size 15 for year 2014 -> they are 14308
# splitted for hole size 15 for year 2015 -> they are 13702
# splitted for hole size 15 for year 2016 -> they are 14861
# splitted for hole size 15 for year 2017 -> they are 14857
# splitted for hole size 15 for year 2018 -> they are 15815
#
#  206973 206973
# ================================================= HOLE SIZE 16 =================================================
# splitted for hole size 16 for year 1990 -> they are 678
# splitted for hole size 16 for year 1991 -> they are 643
# splitted for hole size 16 for year 1992 -> they are 742
# splitted for hole size 16 for year 1993 -> they are 929
# splitted for hole size 16 for year 1994 -> they are 1021
# splitted for hole size 16 for year 1995 -> they are 1237
# splitted for hole size 16 for year 1996 -> they are 1542
# splitted for hole size 16 for year 1997 -> they are 1826
# splitted for hole size 16 for year 1998 -> they are 2279
# splitted for hole size 16 for year 1999 -> they are 1964
# splitted for hole size 16 for year 2000 -> they are 2792
# splitted for hole size 16 for year 2001 -> they are 3422
# splitted for hole size 16 for year 2002 -> they are 6276
# splitted for hole size 16 for year 2003 -> they are 6055
# splitted for hole size 16 for year 2004 -> they are 6768
# splitted for hole size 16 for year 2005 -> they are 7142
# splitted for hole size 16 for year 2006 -> they are 9381
# splitted for hole size 16 for year 2007 -> they are 9871
# splitted for hole size 16 for year 2008 -> they are 11557
# splitted for hole size 16 for year 2009 -> they are 11485
# splitted for hole size 16 for year 2010 -> they are 11919
# splitted for hole size 16 for year 2011 -> they are 11777
# splitted for hole size 16 for year 2012 -> they are 12640
# splitted for hole size 16 for year 2013 -> they are 12827
# splitted for hole size 16 for year 2014 -> they are 14340
# splitted for hole size 16 for year 2015 -> they are 13721
# splitted for hole size 16 for year 2016 -> they are 14892
# splitted for hole size 16 for year 2017 -> they are 14878
# splitted for hole size 16 for year 2018 -> they are 15849
#
#  210453 210453
# ================================================= HOLE SIZE 17 =================================================
# splitted for hole size 17 for year 1990 -> they are 711
# splitted for hole size 17 for year 1991 -> they are 669
# splitted for hole size 17 for year 1992 -> they are 776
# splitted for hole size 17 for year 1993 -> they are 958
# splitted for hole size 17 for year 1994 -> they are 1055
# splitted for hole size 17 for year 1995 -> they are 1280
# splitted for hole size 17 for year 1996 -> they are 1630
# splitted for hole size 17 for year 1997 -> they are 1926
# splitted for hole size 17 for year 1998 -> they are 2419
# splitted for hole size 17 for year 1999 -> they are 2117
# splitted for hole size 17 for year 2000 -> they are 3407
# splitted for hole size 17 for year 2001 -> they are 4671
# splitted for hole size 17 for year 2002 -> they are 6340
# splitted for hole size 17 for year 2003 -> they are 6105
# splitted for hole size 17 for year 2004 -> they are 6791
# splitted for hole size 17 for year 2005 -> they are 7159
# splitted for hole size 17 for year 2006 -> they are 9400
# splitted for hole size 17 for year 2007 -> they are 9882
# splitted for hole size 17 for year 2008 -> they are 11581
# splitted for hole size 17 for year 2009 -> they are 11505
# splitted for hole size 17 for year 2010 -> they are 11940
# splitted for hole size 17 for year 2011 -> they are 11792
# splitted for hole size 17 for year 2012 -> they are 12666
# splitted for hole size 17 for year 2013 -> they are 12853
# splitted for hole size 17 for year 2014 -> they are 14360
# splitted for hole size 17 for year 2015 -> they are 13740
# splitted for hole size 17 for year 2016 -> they are 14927
# splitted for hole size 17 for year 2017 -> they are 14909
# splitted for hole size 17 for year 2018 -> they are 15871
#
#  213440 213440
# ================================================= HOLE SIZE 18 =================================================
# splitted for hole size 18 for year 1990 -> they are 733
# splitted for hole size 18 for year 1991 -> they are 690
# splitted for hole size 18 for year 1992 -> they are 802
# splitted for hole size 18 for year 1993 -> they are 999
# splitted for hole size 18 for year 1994 -> they are 1105
# splitted for hole size 18 for year 1995 -> they are 1344
# splitted for hole size 18 for year 1996 -> they are 1711
# splitted for hole size 18 for year 1997 -> they are 2079
# splitted for hole size 18 for year 1998 -> they are 2587
# splitted for hole size 18 for year 1999 -> they are 2623
# splitted for hole size 18 for year 2000 -> they are 4666
# splitted for hole size 18 for year 2001 -> they are 4717
# splitted for hole size 18 for year 2002 -> they are 6364
# splitted for hole size 18 for year 2003 -> they are 6124
# splitted for hole size 18 for year 2004 -> they are 6818
# splitted for hole size 18 for year 2005 -> they are 7173
# splitted for hole size 18 for year 2006 -> they are 9409
# splitted for hole size 18 for year 2007 -> they are 9892
# splitted for hole size 18 for year 2008 -> they are 11593
# splitted for hole size 18 for year 2009 -> they are 11522
# splitted for hole size 18 for year 2010 -> they are 11952
# splitted for hole size 18 for year 2011 -> they are 11810
# splitted for hole size 18 for year 2012 -> they are 12681
# splitted for hole size 18 for year 2013 -> they are 12882
# splitted for hole size 18 for year 2014 -> they are 14377
# splitted for hole size 18 for year 2015 -> they are 13763
# splitted for hole size 18 for year 2016 -> they are 14944
# splitted for hole size 18 for year 2017 -> they are 14923
# splitted for hole size 18 for year 2018 -> they are 15892
#
#  216175 216175
# ================================================= HOLE SIZE 19 =================================================
# splitted for hole size 19 for year 1990 -> they are 763
# splitted for hole size 19 for year 1991 -> they are 715
# splitted for hole size 19 for year 1992 -> they are 835
# splitted for hole size 19 for year 1993 -> they are 1041
# splitted for hole size 19 for year 1994 -> they are 1160
# splitted for hole size 19 for year 1995 -> they are 1414
# splitted for hole size 19 for year 1996 -> they are 1821
# splitted for hole size 19 for year 1997 -> they are 2254
# splitted for hole size 19 for year 1998 -> they are 3169
# splitted for hole size 19 for year 1999 -> they are 3766
# splitted for hole size 19 for year 2000 -> they are 4722
# splitted for hole size 19 for year 2001 -> they are 4746
# splitted for hole size 19 for year 2002 -> they are 6384
# splitted for hole size 19 for year 2003 -> they are 6152
# splitted for hole size 19 for year 2004 -> they are 6835
# splitted for hole size 19 for year 2005 -> they are 7184
# splitted for hole size 19 for year 2006 -> they are 9423
# splitted for hole size 19 for year 2007 -> they are 9899
# splitted for hole size 19 for year 2008 -> they are 11600
# splitted for hole size 19 for year 2009 -> they are 11534
# splitted for hole size 19 for year 2010 -> they are 11967
# splitted for hole size 19 for year 2011 -> they are 11823
# splitted for hole size 19 for year 2012 -> they are 12701
# splitted for hole size 19 for year 2013 -> they are 12898
# splitted for hole size 19 for year 2014 -> they are 14401
# splitted for hole size 19 for year 2015 -> they are 13779
# splitted for hole size 19 for year 2016 -> they are 14960
# splitted for hole size 19 for year 2017 -> they are 14943
# splitted for hole size 19 for year 2018 -> they are 15901
#
#  218790 218790
# ================================================= HOLE SIZE 20 =================================================
# splitted for hole size 20 for year 1990 -> they are 788
# splitted for hole size 20 for year 1991 -> they are 736
# splitted for hole size 20 for year 1992 -> they are 861
# splitted for hole size 20 for year 1993 -> they are 1081
# splitted for hole size 20 for year 1994 -> they are 1222
# splitted for hole size 20 for year 1995 -> they are 1512
# splitted for hole size 20 for year 1996 -> they are 1943
# splitted for hole size 20 for year 1997 -> they are 2747
# splitted for hole size 20 for year 1998 -> they are 4463
# splitted for hole size 20 for year 1999 -> they are 3820
# splitted for hole size 20 for year 2000 -> they are 4751
# splitted for hole size 20 for year 2001 -> they are 4762
# splitted for hole size 20 for year 2002 -> they are 6401
# splitted for hole size 20 for year 2003 -> they are 6165
# splitted for hole size 20 for year 2004 -> they are 6846
# splitted for hole size 20 for year 2005 -> they are 7188
# splitted for hole size 20 for year 2006 -> they are 9435
# splitted for hole size 20 for year 2007 -> they are 9910
# splitted for hole size 20 for year 2008 -> they are 11607
# splitted for hole size 20 for year 2009 -> they are 11541
# splitted for hole size 20 for year 2010 -> they are 11980
# splitted for hole size 20 for year 2011 -> they are 11832
# splitted for hole size 20 for year 2012 -> they are 12708
# splitted for hole size 20 for year 2013 -> they are 12913
# splitted for hole size 20 for year 2014 -> they are 14407
# splitted for hole size 20 for year 2015 -> they are 13796
# splitted for hole size 20 for year 2016 -> they are 14970
# splitted for hole size 20 for year 2017 -> they are 14951
# splitted for hole size 20 for year 2018 -> they are 15921
#
#  221257 221257
# ================================================= HOLE SIZE 21 =================================================
# splitted for hole size 21 for year 1990 -> they are 815
# splitted for hole size 21 for year 1991 -> they are 758
# splitted for hole size 21 for year 1992 -> they are 886
# splitted for hole size 21 for year 1993 -> they are 1130
# splitted for hole size 21 for year 1994 -> they are 1288
# splitted for hole size 21 for year 1995 -> they are 1630
# splitted for hole size 21 for year 1996 -> they are 2361
# splitted for hole size 21 for year 1997 -> they are 3846
# splitted for hole size 21 for year 1998 -> they are 4518
# splitted for hole size 21 for year 1999 -> they are 3842
# splitted for hole size 21 for year 2000 -> they are 4766
# splitted for hole size 21 for year 2001 -> they are 4767
# splitted for hole size 21 for year 2002 -> they are 6410
# splitted for hole size 21 for year 2003 -> they are 6169
# splitted for hole size 21 for year 2004 -> they are 6860
# splitted for hole size 21 for year 2005 -> they are 7195
# splitted for hole size 21 for year 2006 -> they are 9437
# splitted for hole size 21 for year 2007 -> they are 9918
# splitted for hole size 21 for year 2008 -> they are 11614
# splitted for hole size 21 for year 2009 -> they are 11548
# splitted for hole size 21 for year 2010 -> they are 11987
# splitted for hole size 21 for year 2011 -> they are 11838
# splitted for hole size 21 for year 2012 -> they are 12716
# splitted for hole size 21 for year 2013 -> they are 12920
# splitted for hole size 21 for year 2014 -> they are 14415
# splitted for hole size 21 for year 2015 -> they are 13801
# splitted for hole size 21 for year 2016 -> they are 14976
# splitted for hole size 21 for year 2017 -> they are 14961
# splitted for hole size 21 for year 2018 -> they are 15933
#
#  223305 223305
# ================================================= HOLE SIZE 22 =================================================
# splitted for hole size 22 for year 1990 -> they are 838
# splitted for hole size 22 for year 1991 -> they are 781
# splitted for hole size 22 for year 1992 -> they are 916
# splitted for hole size 22 for year 1993 -> they are 1171
# splitted for hole size 22 for year 1994 -> they are 1381
# splitted for hole size 22 for year 1995 -> they are 1974
# splitted for hole size 22 for year 1996 -> they are 3366
# splitted for hole size 22 for year 1997 -> they are 3876
# splitted for hole size 22 for year 1998 -> they are 4549
# splitted for hole size 22 for year 1999 -> they are 3847
# splitted for hole size 22 for year 2000 -> they are 4778
# splitted for hole size 22 for year 2001 -> they are 4770
# splitted for hole size 22 for year 2002 -> they are 6415
# splitted for hole size 22 for year 2003 -> they are 6179
# splitted for hole size 22 for year 2004 -> they are 6869
# splitted for hole size 22 for year 2005 -> they are 7199
# splitted for hole size 22 for year 2006 -> they are 9442
# splitted for hole size 22 for year 2007 -> they are 9924
# splitted for hole size 22 for year 2008 -> they are 11619
# splitted for hole size 22 for year 2009 -> they are 11552
# splitted for hole size 22 for year 2010 -> they are 11994
# splitted for hole size 22 for year 2011 -> they are 11842
# splitted for hole size 22 for year 2012 -> they are 12718
# splitted for hole size 22 for year 2013 -> they are 12930
# splitted for hole size 22 for year 2014 -> they are 14425
# splitted for hole size 22 for year 2015 -> they are 13808
# splitted for hole size 22 for year 2016 -> they are 14982
# splitted for hole size 22 for year 2017 -> they are 14974
# splitted for hole size 22 for year 2018 -> they are 15944
#
#  225063 225063
# ================================================= HOLE SIZE 23 =================================================
# splitted for hole size 23 for year 1990 -> they are 872
# splitted for hole size 23 for year 1991 -> they are 813
# splitted for hole size 23 for year 1992 -> they are 947
# splitted for hole size 23 for year 1993 -> they are 1243
# splitted for hole size 23 for year 1994 -> they are 1621
# splitted for hole size 23 for year 1995 -> they are 2773
# splitted for hole size 23 for year 1996 -> they are 3401
# splitted for hole size 23 for year 1997 -> they are 3906
# splitted for hole size 23 for year 1998 -> they are 4562
# splitted for hole size 23 for year 1999 -> they are 3854
# splitted for hole size 23 for year 2000 -> they are 4788
# splitted for hole size 23 for year 2001 -> they are 4773
# splitted for hole size 23 for year 2002 -> they are 6418
# splitted for hole size 23 for year 2003 -> they are 6184
# splitted for hole size 23 for year 2004 -> they are 6877
# splitted for hole size 23 for year 2005 -> they are 7204
# splitted for hole size 23 for year 2006 -> they are 9445
# splitted for hole size 23 for year 2007 -> they are 9926
# splitted for hole size 23 for year 2008 -> they are 11625
# splitted for hole size 23 for year 2009 -> they are 11556
# splitted for hole size 23 for year 2010 -> they are 11999
# splitted for hole size 23 for year 2011 -> they are 11844
# splitted for hole size 23 for year 2012 -> they are 12724
# splitted for hole size 23 for year 2013 -> they are 12930
# splitted for hole size 23 for year 2014 -> they are 14434
# splitted for hole size 23 for year 2015 -> they are 13816
# splitted for hole size 23 for year 2016 -> they are 14985
# splitted for hole size 23 for year 2017 -> they are 14980
# splitted for hole size 23 for year 2018 -> they are 15952
#
#  226452 226452
# ================================================= HOLE SIZE 24 =================================================
# splitted for hole size 24 for year 1990 -> they are 894
# splitted for hole size 24 for year 1991 -> they are 838
# splitted for hole size 24 for year 1992 -> they are 977
# splitted for hole size 24 for year 1993 -> they are 1502
# splitted for hole size 24 for year 1994 -> they are 2218
# splitted for hole size 24 for year 1995 -> they are 2802
# splitted for hole size 24 for year 1996 -> they are 3421
# splitted for hole size 24 for year 1997 -> they are 3923
# splitted for hole size 24 for year 1998 -> they are 4575
# splitted for hole size 24 for year 1999 -> they are 3859
# splitted for hole size 24 for year 2000 -> they are 4797
# splitted for hole size 24 for year 2001 -> they are 4776
# splitted for hole size 24 for year 2002 -> they are 6421
# splitted for hole size 24 for year 2003 -> they are 6190
# splitted for hole size 24 for year 2004 -> they are 6881
# splitted for hole size 24 for year 2005 -> they are 7211
# splitted for hole size 24 for year 2006 -> they are 9450
# splitted for hole size 24 for year 2007 -> they are 9928
# splitted for hole size 24 for year 2008 -> they are 11629
# splitted for hole size 24 for year 2009 -> they are 11560
# splitted for hole size 24 for year 2010 -> they are 12002
# splitted for hole size 24 for year 2011 -> they are 11850
# splitted for hole size 24 for year 2012 -> they are 12726
# splitted for hole size 24 for year 2013 -> they are 12932
# splitted for hole size 24 for year 2014 -> they are 14438
# splitted for hole size 24 for year 2015 -> they are 13822
# splitted for hole size 24 for year 2016 -> they are 14990
# splitted for hole size 24 for year 2017 -> they are 14985
# splitted for hole size 24 for year 2018 -> they are 15956
#
#  227553 227553
# ================================================= HOLE SIZE 25 =================================================
# splitted for hole size 25 for year 1990 -> they are 922
# splitted for hole size 25 for year 1991 -> they are 861
# splitted for hole size 25 for year 1992 -> they are 1153
# splitted for hole size 25 for year 1993 -> they are 2154
# splitted for hole size 25 for year 1994 -> they are 2245
# splitted for hole size 25 for year 1995 -> they are 2818
# splitted for hole size 25 for year 1996 -> they are 3432
# splitted for hole size 25 for year 1997 -> they are 3925
# splitted for hole size 25 for year 1998 -> they are 4581
# splitted for hole size 25 for year 1999 -> they are 3864
# splitted for hole size 25 for year 2000 -> they are 4801
# splitted for hole size 25 for year 2001 -> they are 4779
# splitted for hole size 25 for year 2002 -> they are 6422
# splitted for hole size 25 for year 2003 -> they are 6192
# splitted for hole size 25 for year 2004 -> they are 6882
# splitted for hole size 25 for year 2005 -> they are 7212
# splitted for hole size 25 for year 2006 -> they are 9452
# splitted for hole size 25 for year 2007 -> they are 9929
# splitted for hole size 25 for year 2008 -> they are 11631
# splitted for hole size 25 for year 2009 -> they are 11562
# splitted for hole size 25 for year 2010 -> they are 12004
# splitted for hole size 25 for year 2011 -> they are 11852
# splitted for hole size 25 for year 2012 -> they are 12726
# splitted for hole size 25 for year 2013 -> they are 12935
# splitted for hole size 25 for year 2014 -> they are 14443
# splitted for hole size 25 for year 2015 -> they are 13824
# splitted for hole size 25 for year 2016 -> they are 14997
# splitted for hole size 25 for year 2017 -> they are 14988
# splitted for hole size 25 for year 2018 -> they are 15961
#
#  228547 228547
# ================================================= HOLE SIZE 26 =================================================
# splitted for hole size 26 for year 1990 -> they are 960
# splitted for hole size 26 for year 1991 -> they are 980
# splitted for hole size 26 for year 1992 -> they are 1578
# splitted for hole size 26 for year 1993 -> they are 2172
# splitted for hole size 26 for year 1994 -> they are 2254
# splitted for hole size 26 for year 1995 -> they are 2827
# splitted for hole size 26 for year 1996 -> they are 3438
# splitted for hole size 26 for year 1997 -> they are 3931
# splitted for hole size 26 for year 1998 -> they are 4583
# splitted for hole size 26 for year 1999 -> they are 3867
# splitted for hole size 26 for year 2000 -> they are 4804
# splitted for hole size 26 for year 2001 -> they are 4781
# splitted for hole size 26 for year 2002 -> they are 6424
# splitted for hole size 26 for year 2003 -> they are 6194
# splitted for hole size 26 for year 2004 -> they are 6885
# splitted for hole size 26 for year 2005 -> they are 7214
# splitted for hole size 26 for year 2006 -> they are 9452
# splitted for hole size 26 for year 2007 -> they are 9931
# splitted for hole size 26 for year 2008 -> they are 11631
# splitted for hole size 26 for year 2009 -> they are 11567
# splitted for hole size 26 for year 2010 -> they are 12004
# splitted for hole size 26 for year 2011 -> they are 11855
# splitted for hole size 26 for year 2012 -> they are 12729
# splitted for hole size 26 for year 2013 -> they are 12938
# splitted for hole size 26 for year 2014 -> they are 14445
# splitted for hole size 26 for year 2015 -> they are 13825
# splitted for hole size 26 for year 2016 -> they are 14999
# splitted for hole size 26 for year 2017 -> they are 14993
# splitted for hole size 26 for year 2018 -> they are 15969
#
#  229230 229230
# ================================================= HOLE SIZE 27 =================================================
# splitted for hole size 27 for year 1990 -> they are 1098
# splitted for hole size 27 for year 1991 -> they are 1351
# splitted for hole size 27 for year 1992 -> they are 1592
# splitted for hole size 27 for year 1993 -> they are 2182
# splitted for hole size 27 for year 1994 -> they are 2263
# splitted for hole size 27 for year 1995 -> they are 2836
# splitted for hole size 27 for year 1996 -> they are 3445
# splitted for hole size 27 for year 1997 -> they are 3934
# splitted for hole size 27 for year 1998 -> they are 4583
# splitted for hole size 27 for year 1999 -> they are 3870
# splitted for hole size 27 for year 2000 -> they are 4807
# splitted for hole size 27 for year 2001 -> they are 4782
# splitted for hole size 27 for year 2002 -> they are 6427
# splitted for hole size 27 for year 2003 -> they are 6196
# splitted for hole size 27 for year 2004 -> they are 6885
# splitted for hole size 27 for year 2005 -> they are 7216
# splitted for hole size 27 for year 2006 -> they are 9452
# splitted for hole size 27 for year 2007 -> they are 9933
# splitted for hole size 27 for year 2008 -> they are 11632
# splitted for hole size 27 for year 2009 -> they are 11570
# splitted for hole size 27 for year 2010 -> they are 12007
# splitted for hole size 27 for year 2011 -> they are 11856
# splitted for hole size 27 for year 2012 -> they are 12730
# splitted for hole size 27 for year 2013 -> they are 12938
# splitted for hole size 27 for year 2014 -> they are 14445
# splitted for hole size 27 for year 2015 -> they are 13828
# splitted for hole size 27 for year 2016 -> they are 15001
# splitted for hole size 27 for year 2017 -> they are 14994
# splitted for hole size 27 for year 2018 -> they are 15971
#
#  229824 229824
# ================================================= HOLE SIZE 28 =================================================
# splitted for hole size 28 for year 1990 -> they are 1497
# splitted for hole size 28 for year 1991 -> they are 1353
# splitted for hole size 28 for year 1992 -> they are 1595
# splitted for hole size 28 for year 1993 -> they are 2182
# splitted for hole size 28 for year 1994 -> they are 2263
# splitted for hole size 28 for year 1995 -> they are 2836
# splitted for hole size 28 for year 1996 -> they are 3445
# splitted for hole size 28 for year 1997 -> they are 3934
# splitted for hole size 28 for year 1998 -> they are 4583
# splitted for hole size 28 for year 1999 -> they are 3870
# splitted for hole size 28 for year 2000 -> they are 4807
# splitted for hole size 28 for year 2001 -> they are 4782
# splitted for hole size 28 for year 2002 -> they are 6427
# splitted for hole size 28 for year 2003 -> they are 6197
# splitted for hole size 28 for year 2004 -> they are 6886
# splitted for hole size 28 for year 2005 -> they are 7216
# splitted for hole size 28 for year 2006 -> they are 9453
# splitted for hole size 28 for year 2007 -> they are 9933
# splitted for hole size 28 for year 2008 -> they are 11632
# splitted for hole size 28 for year 2009 -> they are 11570
# splitted for hole size 28 for year 2010 -> they are 12007
# splitted for hole size 28 for year 2011 -> they are 11856
# splitted for hole size 28 for year 2012 -> they are 12730
# splitted for hole size 28 for year 2013 -> they are 12938
# splitted for hole size 28 for year 2014 -> they are 14445
# splitted for hole size 28 for year 2015 -> they are 13828
# splitted for hole size 28 for year 2016 -> they are 15001
# splitted for hole size 28 for year 2017 -> they are 14994
# splitted for hole size 28 for year 2018 -> they are 15974
#
#  230234 230234
