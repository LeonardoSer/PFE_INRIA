# %%
import itertools
import random
import json
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path 
import sys
import threading
import os
from IPython.display import clear_output

# %%
## Find the starting collaboration year for each author
def get_start_Y(df, id):
    aut = df.loc[df["ID"] == id]
    start_year = 0
    for year in aut.columns[1:]:
        n_colls = aut[year].values[0]
        
        if(n_colls != 0):
            start_year = year
        return start_year

## return all IDs of authors that have started to collaborate in the given year
 # param 'year' is a String
def get_authors_by_Y(year, df): 
    i = 0
    IDs = []
    
    for id in df["ID"]:
        aut = df.loc[df["ID"] == id]
        start_y = get_start_Y(df, id)
        
        if(year == start_y):
            IDs.append(aut["ID"].values[0])
            
        i += 1
        
        #clear_output(wait=True)
        if(i%1000==0):
            print(i, "/", len(df["ID"]), " for year: ", year, end='\r')
        
    return IDs

# %%
## This method return a DF for the given year, containing the timeseries of each author that starterd to collaborate on that year
def splitDF_by_start_Y(df, y):
    
    YEARS = [str(year) for year in range(1990,2019)]    
    i = YEARS.index(str(y))

    IDs = get_authors_by_Y(YEARS[i], df)
    start_y_Dfs = df[df.ID.isin(IDs)]

    cols = YEARS[i:]
    cols.insert(0, "ID")
    
    return start_y_Dfs[cols]

# %%
min_size = 0
max_size = 28

# Read active authors by hole lenght
for size in range(min_size, max_size+1):
    path = 'myDATA/05-filtered_by_hole_size/filtered_by_hole_size_'+str(size)+'.csv'
    
    if os.path.exists(path) and not os.path.exists('myDATA/10-splitted_by_hole_size_'+str(size)):
        df = pd.read_csv(path)
        os.mkdir('myDATA/10-splitted_by_hole_size_'+str(size))
        
        YEARS = [str(year) for year in range(1990,2019)]    
        for y in YEARS:
            print("splitting for hole size " + str(size) + " for year " + y + "\n", end='\r')
            # write a .csv for each year Y with all authors that started collaborating in Y.
             # it contains their collaborations form Y until 2018
            df_y = splitDF_by_start_Y(df, y)
            df_y.to_csv('myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv', index=False)
# Out:
# splitting for hole size 13 for year 1990
# splitting for hole size 13 for year 1991
# splitting for hole size 13 for year 1992
# splitting for hole size 13 for year 1993
# splitting for hole size 13 for year 1994
# splitting for hole size 13 for year 1995
# splitting for hole size 13 for year 1996
# splitting for hole size 13 for year 1997
# splitting for hole size 13 for year 1998
# splitting for hole size 13 for year 1999
# splitting for hole size 13 for year 2000
# splitting for hole size 13 for year 2001
# splitting for hole size 13 for year 2002
# splitting for hole size 13 for year 2003
# splitting for hole size 13 for year 2004
# splitting for hole size 13 for year 2005
# splitting for hole size 13 for year 2006
# splitting for hole size 13 for year 2007
# splitting for hole size 13 for year 2008
# splitting for hole size 13 for year 2009
# splitting for hole size 13 for year 2010
# splitting for hole size 13 for year 2011
# splitting for hole size 13 for year 2012
# splitting for hole size 13 for year 2013
# splitting for hole size 13 for year 2014
# splitting for hole size 13 for year 2015
# splitting for hole size 13 for year 2016
# splitting for hole size 13 for year 2017
# splitting for hole size 13 for year 2018
# splitting for hole size 14 for year 1990
# splitting for hole size 14 for year 1991
# splitting for hole size 14 for year 1992
# splitting for hole size 14 for year 1993
# splitting for hole size 14 for year 1994
# splitting for hole size 14 for year 1995
# splitting for hole size 14 for year 1996
# splitting for hole size 14 for year 1997
# splitting for hole size 14 for year 1998
# splitting for hole size 14 for year 1999
# splitting for hole size 14 for year 2000
# splitting for hole size 14 for year 2001
# splitting for hole size 14 for year 2002
# splitting for hole size 14 for year 2003
# splitting for hole size 14 for year 2004
# splitting for hole size 14 for year 2005
# splitting for hole size 14 for year 2006
# splitting for hole size 14 for year 2007
# splitting for hole size 14 for year 2008
# splitting for hole size 14 for year 2009
# splitting for hole size 14 for year 2010
# splitting for hole size 14 for year 2011
# splitting for hole size 14 for year 2012
# splitting for hole size 14 for year 2013
# splitting for hole size 14 for year 2014
# splitting for hole size 14 for year 2015
# splitting for hole size 14 for year 2016
# splitting for hole size 14 for year 2017
# splitting for hole size 14 for year 2018
# splitting for hole size 15 for year 1990
# splitting for hole size 15 for year 1991
# splitting for hole size 15 for year 1992
# splitting for hole size 15 for year 1993
# splitting for hole size 15 for year 1994
# splitting for hole size 15 for year 1995
# splitting for hole size 15 for year 1996
# splitting for hole size 15 for year 1997
# splitting for hole size 15 for year 1998
# splitting for hole size 15 for year 1999
# splitting for hole size 15 for year 2000
# splitting for hole size 15 for year 2001
# splitting for hole size 15 for year 2002
# splitting for hole size 15 for year 2003
# splitting for hole size 15 for year 2004
# splitting for hole size 15 for year 2005
# splitting for hole size 15 for year 2006
# splitting for hole size 15 for year 2007
# splitting for hole size 15 for year 2008
# splitting for hole size 15 for year 2009
# splitting for hole size 15 for year 2010
# splitting for hole size 15 for year 2011
# splitting for hole size 15 for year 2012
# splitting for hole size 15 for year 2013
# splitting for hole size 15 for year 2014
# splitting for hole size 15 for year 2015
# splitting for hole size 15 for year 2016
# splitting for hole size 15 for year 2017
# splitting for hole size 15 for year 2018
# splitting for hole size 16 for year 1990
# splitting for hole size 16 for year 1991
# splitting for hole size 16 for year 1992
# splitting for hole size 16 for year 1993
# splitting for hole size 16 for year 1994
# splitting for hole size 16 for year 1995
# splitting for hole size 16 for year 1996
# splitting for hole size 16 for year 1997
# splitting for hole size 16 for year 1998
# splitting for hole size 16 for year 1999
# splitting for hole size 16 for year 2000
# splitting for hole size 16 for year 2001
# splitting for hole size 16 for year 2002
# splitting for hole size 16 for year 2003
# splitting for hole size 16 for year 2004
# splitting for hole size 16 for year 2005
# splitting for hole size 16 for year 2006
# splitting for hole size 16 for year 2007
# splitting for hole size 16 for year 2008
# splitting for hole size 16 for year 2009
# splitting for hole size 16 for year 2010
# splitting for hole size 16 for year 2011
# splitting for hole size 16 for year 2012
# splitting for hole size 16 for year 2013
# splitting for hole size 16 for year 2014
# splitting for hole size 16 for year 2015
# splitting for hole size 16 for year 2016
# splitting for hole size 16 for year 2017
# splitting for hole size 16 for year 2018
# splitting for hole size 17 for year 1990
# splitting for hole size 17 for year 1991
# splitting for hole size 17 for year 1992
# splitting for hole size 17 for year 1993
# splitting for hole size 17 for year 1994
# splitting for hole size 17 for year 1995
# splitting for hole size 17 for year 1996
# splitting for hole size 17 for year 1997
# splitting for hole size 17 for year 1998
# splitting for hole size 17 for year 1999
# splitting for hole size 17 for year 2000
# splitting for hole size 17 for year 2001
# splitting for hole size 17 for year 2002
# splitting for hole size 17 for year 2003
# splitting for hole size 17 for year 2004
# splitting for hole size 17 for year 2005
# splitting for hole size 17 for year 2006
# splitting for hole size 17 for year 2007
# splitting for hole size 17 for year 2008
# splitting for hole size 17 for year 2009
# splitting for hole size 17 for year 2010
# splitting for hole size 17 for year 2011
# splitting for hole size 17 for year 2012
# splitting for hole size 17 for year 2013
# splitting for hole size 17 for year 2014
# splitting for hole size 17 for year 2015
# splitting for hole size 17 for year 2016
# splitting for hole size 17 for year 2017
# splitting for hole size 17 for year 2018
# splitting for hole size 18 for year 1990
# splitting for hole size 18 for year 1991
# splitting for hole size 18 for year 1992
# splitting for hole size 18 for year 1993
# splitting for hole size 18 for year 1994
# splitting for hole size 18 for year 1995
# splitting for hole size 18 for year 1996
# splitting for hole size 18 for year 1997
# splitting for hole size 18 for year 1998
# splitting for hole size 18 for year 1999
# splitting for hole size 18 for year 2000
# splitting for hole size 18 for year 2001
# splitting for hole size 18 for year 2002
# splitting for hole size 18 for year 2003
# splitting for hole size 18 for year 2004
# splitting for hole size 18 for year 2005
# splitting for hole size 18 for year 2006
# splitting for hole size 18 for year 2007
# splitting for hole size 18 for year 2008
# splitting for hole size 18 for year 2009
# splitting for hole size 18 for year 2010
# splitting for hole size 18 for year 2011
# splitting for hole size 18 for year 2012
# splitting for hole size 18 for year 2013
# splitting for hole size 18 for year 2014
# splitting for hole size 18 for year 2015
# splitting for hole size 18 for year 2016
# splitting for hole size 18 for year 2017
# splitting for hole size 18 for year 2018
# splitting for hole size 19 for year 1990
# splitting for hole size 19 for year 1991
# splitting for hole size 19 for year 1992
# splitting for hole size 19 for year 1993
# splitting for hole size 19 for year 1994
# splitting for hole size 19 for year 1995
# splitting for hole size 19 for year 1996
# splitting for hole size 19 for year 1997
# splitting for hole size 19 for year 1998
# splitting for hole size 19 for year 1999
# splitting for hole size 19 for year 2000
# splitting for hole size 19 for year 2001
# splitting for hole size 19 for year 2002
# splitting for hole size 19 for year 2003
# splitting for hole size 19 for year 2004
# splitting for hole size 19 for year 2005
# splitting for hole size 19 for year 2006
# splitting for hole size 19 for year 2007
# splitting for hole size 19 for year 2008
# splitting for hole size 19 for year 2009
# splitting for hole size 19 for year 2010
# splitting for hole size 19 for year 2011
# splitting for hole size 19 for year 2012
# splitting for hole size 19 for year 2013
# splitting for hole size 19 for year 2014
# splitting for hole size 19 for year 2015
# splitting for hole size 19 for year 2016
# splitting for hole size 19 for year 2017
# splitting for hole size 19 for year 2018
# splitting for hole size 20 for year 1990
# splitting for hole size 20 for year 1991
# splitting for hole size 20 for year 1992
# splitting for hole size 20 for year 1993
# splitting for hole size 20 for year 1994
# splitting for hole size 20 for year 1995
# splitting for hole size 20 for year 1996
# splitting for hole size 20 for year 1997
# splitting for hole size 20 for year 1998
# splitting for hole size 20 for year 1999
# splitting for hole size 20 for year 2000
# splitting for hole size 20 for year 2001
# splitting for hole size 20 for year 2002
# splitting for hole size 20 for year 2003
# splitting for hole size 20 for year 2004
# splitting for hole size 20 for year 2005
# splitting for hole size 20 for year 2006
# splitting for hole size 20 for year 2007
# splitting for hole size 20 for year 2008
# splitting for hole size 20 for year 2009
# splitting for hole size 20 for year 2010
# splitting for hole size 20 for year 2011
# splitting for hole size 20 for year 2012
# splitting for hole size 20 for year 2013
# splitting for hole size 20 for year 2014
# splitting for hole size 20 for year 2015
# splitting for hole size 20 for year 2016
# splitting for hole size 20 for year 2017
# splitting for hole size 20 for year 2018
# splitting for hole size 21 for year 1990
# splitting for hole size 21 for year 1991
# splitting for hole size 21 for year 1992
# splitting for hole size 21 for year 1993
# splitting for hole size 21 for year 1994
# splitting for hole size 21 for year 1995
# splitting for hole size 21 for year 1996
# splitting for hole size 21 for year 1997
# splitting for hole size 21 for year 1998
# splitting for hole size 21 for year 1999
# splitting for hole size 21 for year 2000
# splitting for hole size 21 for year 2001
# splitting for hole size 21 for year 2002
# splitting for hole size 21 for year 2003
# splitting for hole size 21 for year 2004
# splitting for hole size 21 for year 2005
# splitting for hole size 21 for year 2006
# splitting for hole size 21 for year 2007
# splitting for hole size 21 for year 2008
# splitting for hole size 21 for year 2009
# splitting for hole size 21 for year 2010
# splitting for hole size 21 for year 2011
# splitting for hole size 21 for year 2012
# splitting for hole size 21 for year 2013
# splitting for hole size 21 for year 2014
# splitting for hole size 21 for year 2015
# splitting for hole size 21 for year 2016
# splitting for hole size 21 for year 2017
# splitting for hole size 21 for year 2018
# splitting for hole size 22 for year 1990
# splitting for hole size 22 for year 1991
# splitting for hole size 22 for year 1992
# splitting for hole size 22 for year 1993
# splitting for hole size 22 for year 1994
# splitting for hole size 22 for year 1995
# splitting for hole size 22 for year 1996
# splitting for hole size 22 for year 1997
# splitting for hole size 22 for year 1998
# splitting for hole size 22 for year 1999
# splitting for hole size 22 for year 2000
# splitting for hole size 22 for year 2001
# splitting for hole size 22 for year 2002
# splitting for hole size 22 for year 2003
# splitting for hole size 22 for year 2004
# splitting for hole size 22 for year 2005
# splitting for hole size 22 for year 2006
# splitting for hole size 22 for year 2007
# splitting for hole size 22 for year 2008
# splitting for hole size 22 for year 2009
# splitting for hole size 22 for year 2010
# splitting for hole size 22 for year 2011
# splitting for hole size 22 for year 2012
# splitting for hole size 22 for year 2013
# splitting for hole size 22 for year 2014
# splitting for hole size 22 for year 2015
# splitting for hole size 22 for year 2016
# splitting for hole size 22 for year 2017
# splitting for hole size 22 for year 2018
# splitting for hole size 23 for year 1990
# splitting for hole size 23 for year 1991
# splitting for hole size 23 for year 1992
# splitting for hole size 23 for year 1993
# splitting for hole size 23 for year 1994
# splitting for hole size 23 for year 1995
# splitting for hole size 23 for year 1996
# splitting for hole size 23 for year 1997
# splitting for hole size 23 for year 1998
# splitting for hole size 23 for year 1999
# splitting for hole size 23 for year 2000
# splitting for hole size 23 for year 2001
# splitting for hole size 23 for year 2002
# splitting for hole size 23 for year 2003
# splitting for hole size 23 for year 2004
# splitting for hole size 23 for year 2005
# splitting for hole size 23 for year 2006
# splitting for hole size 23 for year 2007
# splitting for hole size 23 for year 2008
# splitting for hole size 23 for year 2009
# splitting for hole size 23 for year 2010
# splitting for hole size 23 for year 2011
# splitting for hole size 23 for year 2012
# splitting for hole size 23 for year 2013
# splitting for hole size 23 for year 2014
# splitting for hole size 23 for year 2015
# splitting for hole size 23 for year 2016
# splitting for hole size 23 for year 2017
# splitting for hole size 23 for year 2018
# splitting for hole size 24 for year 1990
# splitting for hole size 24 for year 1991
# splitting for hole size 24 for year 1992
# splitting for hole size 24 for year 1993
# splitting for hole size 24 for year 1994
# splitting for hole size 24 for year 1995
# splitting for hole size 24 for year 1996
# splitting for hole size 24 for year 1997
# splitting for hole size 24 for year 1998
# splitting for hole size 24 for year 1999
# splitting for hole size 24 for year 2000
# splitting for hole size 24 for year 2001
# splitting for hole size 24 for year 2002
# splitting for hole size 24 for year 2003
# splitting for hole size 24 for year 2004
# splitting for hole size 24 for year 2005
# splitting for hole size 24 for year 2006
# splitting for hole size 24 for year 2007
# splitting for hole size 24 for year 2008
# splitting for hole size 24 for year 2009
# splitting for hole size 24 for year 2010
# splitting for hole size 24 for year 2011
# splitting for hole size 24 for year 2012
# splitting for hole size 24 for year 2013
# splitting for hole size 24 for year 2014
# splitting for hole size 24 for year 2015
# splitting for hole size 24 for year 2016
# splitting for hole size 24 for year 2017
# splitting for hole size 24 for year 2018
# splitting for hole size 26 for year 1990
# 5000 / 231744  for year:  1990
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-6f013086ee13> in <module>
#      15             # write a .csv for each year Y with all authors that started collaborating in Y.
#      16              # it contains their collaborations form Y until 2018
# ---> 17             df_y = splitDF_by_start_Y(df, y)
#      18             df_y.to_csv('myDATA/10-splitted_by_hole_size_'+str(size)+'/collabs_by_year_'+y+'.csv', index=False)
#
# <ipython-input-3-db4be2cb0613> in splitDF_by_start_Y(df, y)
#       5     i = YEARS.index(str(y))
#       6
# ----> 7     IDs = get_authors_by_Y(YEARS[i], df)
#       8     start_y_Dfs = df[df.ID.isin(IDs)]
#       9
#
# <ipython-input-2-f752f424eb37> in get_authors_by_Y(year, df)
#      18     for id in df["ID"]:
#      19         aut = df.loc[df["ID"] == id]
# ---> 20         start_y = get_start_Y(df, id)
#      21
#      22         if(year == start_y):
#
# <ipython-input-2-f752f424eb37> in get_start_Y(df, id)
#       1 ## Find the starting collaboration year for each author
#       2 def get_start_Y(df, id):
# ----> 3     aut = df.loc[df["ID"] == id]
#       4     start_year = 0
#       5     for year in aut.columns[1:]:
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
# -> 1144             return self._getbool_axis(key, axis=axis)
#    1145         elif is_list_like_indexer(key):
#    1146
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     948         key = check_bool_indexer(labels, key)
#     949         inds = key.nonzero()[0]
# --> 950         return self.obj._take_with_is_copy(inds, axis=axis)
#     951
#     952
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in _take_with_is_copy(self, indices, axis)
#    3623         See the docstring of `take` for full explanation of the parameters.
#    3624         """
# -> 3625         result = self.take(indices=indices, axis=axis)
#    3626         # Maybe set copy if we didn't actually change the index.
#    3627         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3610         self._consolidate_inplace()
#    3611
# -> 3612         new_data = self._mgr.take(
#    3613             indices, axis=self._get_block_manager_axis(axis), verify=True
#    3614         )
#
# ~/.local/lib/python3.8/site-packages/pandas/core/internals/managers.py in take(self, indexer, axis, verify)
#     853
#     854         n = self.shape[axis]
# --> 855         indexer = maybe_convert_indices(indexer, n, verify=verify)
#     856
#     857         new_labels = self.axes[axis].take(indexer)
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexers.py in maybe_convert_indices(indices, n, verify)
#     289     if verify:
#     290         mask = (indices >= n) | (indices < 0)
# --> 291         if mask.any():
#     292             raise IndexError("indices are out-of-bounds")
#     293     return indices
#
# ~/.local/lib/python3.8/site-packages/numpy/core/_methods.py in _any(a, axis, dtype, out, keepdims, where)
#      54     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      55     if where is True:
# ---> 56         return umr_any(a, axis, dtype, out, keepdims)
#      57     return umr_any(a, axis, dtype, out, keepdims, where=where)
#      58
#
# KeyboardInterrupt:
